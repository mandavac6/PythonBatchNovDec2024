# %% [markdown]
# ### Shelve
#
#     stores in .db files

# %%
import shelve

# %%
dir(shelve)
# Out:
# ['BsdDbShelf',
#  'BytesIO',
#  'DEFAULT_PROTOCOL',
#  'DbfilenameShelf',
#  'Pickler',
#  'Shelf',
#  'Unpickler',
#  '_ClosedDict',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'collections',
#  'open']

# %%
s = shelve.open("myshelve.db")

s["key1"] = {"int": 10, "float": 9.5, "string": "Sample data"}

s["persondetails"] = person_details ={
    "name": "Tom Brady", 
    "age": 45,
    "location": 'USA'
}

s.close()

# %%
! ls -ltr
# Out:
# total 152
# -rw-rw-rw- 1 codespace codespace    38 Jan  7 01:08 data.pickle
# -rw-rw-rw- 1 codespace codespace    66 Jan  7 01:08 data.pickle.gz
# -rw-rw-rw- 1 codespace codespace    93 Jan  7 01:10 person_details.pkl
# -rw-rw-rw- 1 codespace codespace 28686 Jan  7 01:13 a_pickle.ipynb
# -rw-rw-rw- 1 codespace codespace 90841 Jan  7 01:24 b_shelve.ipynb
# -rw-rw-rw- 1 codespace codespace 16384 Jan  7 01:25 myshelve.db

# %%
! cat myshelve.db
# Out:
# <��������������������������������������������������������������������������������������������������������������������������������������������������������������������f��Gkey10@��������������������������������������������������������������������������������������������������������������������key1��5}�(�int�K                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                s�0����������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������J�R?persD0
# �float�G@#�string��Sample data�u.persondetails��1}�(�name��	Tom Brady��age�K-location��USA�u.

# %%
s = shelve.open("myshelve.db")
existing = s["key1"]
print(existing)
s.close()
# Out:
# {'int': 10, 'float': 9.5, 'string': 'Sample data'}

# %%
with shelve.open("myshelve.db") as fh:
    print("before:", fh['key1'])

    fh['key1']['new_value']= "this was not here before"

    print("after:", fh['key1'])
# Out:
# before: {'int': 10, 'float': 9.5, 'string': 'Sample data'}
# after: {'int': 10, 'float': 9.5, 'string': 'Sample data'}

# %%
s = shelve.open("myshelve.db")
print(s['key1'])
s.close()
# Out:
# {'int': 10, 'float': 9.5, 'string': 'Sample data'}

# %%
s= shelve.open("myshelve.db", writeback = True)
print("before:", s['key1'])

s['key1']['new_value']= "this was not here before"

print("after:", s['key1'])
# Out:
# before: {'int': 10, 'float': 9.5, 'string': 'Sample data'}
# after: {'int': 10, 'float': 9.5, 'string': 'Sample data', 'new_value': 'this was not here before'}

# %%
# Note: Shelve must not be opened with writeback enabled,  unless it is essential
